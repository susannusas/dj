# %% [markdown]
# --class:data journalism 2020 jinan university
#
#
# 1. 导入lib和数据输入
#
# 2. 基本统计量
#
# 3. python探索性统计／描述性统计
#
# 4. 基本统计量的可视化
#
#
#
#
# by: tsusanliu@jnu.edu.cn
#
# --textbook and reference
#
# 王斌会,王术 等. (2019). Python数据挖掘方法及应用. 电子工业出版社.
#
# # 导入lib和数据输入

# %%
import numpy as np   
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager
# %matplotlib inline          
#显示图形
plt.figure(figsize=(5,4));
#指定默认字体
plt.rcParams['font.family']='sans-serif'
plt.rcParams['font.sans-serif']=['KaiTi']

#解决负号'-'显示为方块的问题
plt.rcParams['axes.unicode_minus'] = False

# %%
bsdata=pd.read_clipboard();
bsdata[:5]
# Out:
#            学号 性别   身高  体重    支出   开设    课程      软件
# 0  1510248008  女  167  71  46.0  不清楚  都未学过      No
# 1  1510229019  男  171  68  10.4  有必要  概率统计  Matlab
# 2  1512108019  女  175  73  21.0  有必要  统计方法    SPSS
# 3  1512332010  男  169  74   4.9  有必要  编程技术   Excel
# 4  1512331015  男  154  55  25.9  有必要  都学习过  Python

# %%
#r for i in 1:5b
for i in bsdata.columns:
    print(i)
# Out:
# 学号
# 性别
# 身高
# 体重
# 支出
# 开设
# 课程
# 软件

# %% [markdown]
# # 基本统计量

# %%
x=10
if x>10:
    print('no')
else: 
    print('yes')
# Out:
# yes

# %%
x=[1,3,6,4,9,7,5,8,2];x
# Out:
# [1, 3, 6, 4, 9, 7, 5, 8, 2]

# %%
sum(x)
# Out:
# 45

# %%
np.mean(x)
# Out:
# 5.0

# %%
def xbar(x):       #    xbar<function(x)>    函数编写 python和r
    n=len(x);x      #    length(x)
    xbar=sum(x)/n;xbar    #    xbar=sum(x)/n
    return(xbar)        #    return xbar

# %%
xbar(x)
# Out:
# 5.0

# %% [markdown]
# # python探索性统计／描述性统计
#
# textbook chapter 2

# %%
bsdata.describe()  #summary[bsdata]
# Out:
#                  学号          身高         体重         支出
# count  5.200000e+01   52.000000  52.000000  52.000000
# mean   1.523270e+09  168.519231  68.500000  24.511538
# std    1.899525e+07    8.018338   7.711718  21.432060
# min    1.438120e+09  154.000000  50.000000   2.500000
# 25%    1.520377e+09  163.000000  63.000000   9.500000
# 50%    1.526685e+09  167.500000  68.500000  15.450000
# 75%    1.532229e+09  174.000000  73.000000  35.600000
# max    1.540388e+09  186.000000  87.000000  85.600000

# %%
bsdata[['学号']].describe()
# Out:
#                  学号
# count  5.200000e+01
# mean   1.523270e+09
# std    1.899525e+07
# min    1.438120e+09
# 25%    1.520377e+09
# 50%    1.526685e+09
# 75%    1.532229e+09
# max    1.540388e+09

# %%
bsdata.性别.value_counts()
# Out:
# 男    27
# 女    25
# Name: 性别, dtype: int64

# %%
bsdata['开设'].value_counts()
# Out:
# 有必要    29
# 不清楚    12
# 不必要    11
# Name: 开设, dtype: int64

# %%
bsdata['性别'].value_counts()
# Out:
# 男    27
# 女    25
# Name: 性别, dtype: int64

# %%
bsdata.支出.mean()
# Out:
# 24.51153846153846

# %%
bsdata.支出.median()
# Out:
# 15.45

# %% [markdown]
# ## practice：请计算最高和最矮同学的身高差是多少？

# %%
#???
# Out:
# 32

# %%
bsdata.身高.std()
# Out:
# 8.01833776871194

# %%
bsdata.身高.quantile(0.25)  #    np.quantile(bsdata.身高,0.25)  r 函数写在前面，pyhon 面向对象，函数写在后面
# Out:
# 163.0

# %%
bsdata.身高.kurt()
# Out:
# -0.42072371559816935

# %%
bsdata.身高.skew()
# Out:
# 0.29880755120910174

# %%
T1=bsdata.身高.value_counts();T1
# Out:
# 169    4
# 163    4
# 166    4
# 178    3
# 164    3
# 167    3
# 158    2
# 160    2
# 175    2
# 165    2
# 173    2
# 171    2
# 155    2
# 168    2
# 174    2
# 156    1
# 159    1
# 162    1
# 186    1
# 185    1
# 170    1
# 172    1
# 176    1
# 179    1
# 180    1
# 183    1
# 184    1
# 154    1
# Name: 身高, dtype: int64

# %% [markdown]
# # 基本统计量的可视化

# %%
plt.bar(T1.index,T1);
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## 请画出全班同学的支出

# %%
# Out:
# <BarContainer object of 52 artists>

# %%
#X=['A','B','C','D','E']
X=[1,2,3,4,5]
Y=[1,3,6,4,9]
plt.bar(X,Y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.hist(bsdata.身高)
# Out:
# (array([4., 5., 5., 9., 9., 6., 5., 4., 1., 4.]),
#  array([154. , 157.2, 160.4, 163.6, 166.8, 170. , 173.2, 176.4, 179.6,
#         182.8, 186. ]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(X,Y,c='red');
plt.xlabel('X');plt.ylabel('Y');
plt.title('折线图');plt.ylim(0,10)
# Out:
# (0, 10)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 25240 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 32447 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 25240 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 32447 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
bsdata.身高.plot()

# %%
bsdata.身高.plot(kind='box')
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 36523 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 36523 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
bsdata.身高.plot(kind='kde')

# %%
bsdata[['身高','体重','支出']].plot(kind='density')
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 36523 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 20307 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 37325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 25903 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
bsdata[['身高','体重','支出']].plot(subplots=True,kind='density')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e0eea90>,
# ...
#       dtype=object)

# %%
T1.plot(kind='bar')

# %%
T1.plot(kind='pie')

# %%
type(T1)
# Out:
# pandas.core.series.Series

# %%
pd.crosstab(bsdata.开设,bsdata.课程).plot(kind='barh')
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 19981 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 35201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 28165 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26970 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
pd.crosstab(bsdata.课程,bsdata.开设).plot(kind='barh')

# %%
pd.cut(bsdata.身高,bins=10).value_counts().plot(kind ='bar')

# %%
type(bsdata.groupby(['性别']))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
round(bsdata.groupby(['性别']).mean(),2)
# Out:
#               学号      身高     体重     支出
# 性别
# 女   1.524349e+09  165.36  66.24  26.99
# 男   1.522271e+09  171.44  70.59  22.21

# %%
bsdata.groupby(['性别'])['身高'].agg([len,np.mean,np.std])
# Out:
#     len        mean       std
# 性别
# 女    25  165.360000  5.179125
# 男    27  171.444444  9.103395

# %%
bsdata.pivot_table(index=['性别'],columns=['身高'],aggfunc=len).plot()
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 22899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 30007 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 22899 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 30007 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
bsdata.pivot_table(index=['性别'],columns=['身高'],aggfunc=len,margins=True).plot()
